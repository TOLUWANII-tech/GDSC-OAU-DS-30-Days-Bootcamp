# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('GDP.csv')

# %%
df
# Out:
#            DATE        GDP
# 0    1947-01-01    243.164
# 1    1947-04-01    245.968
# 2    1947-07-01    249.585
# 3    1947-10-01    259.745
# 4    1948-01-01    265.742
# ..          ...        ...
# 285  2018-04-01  20510.177
# 286  2018-07-01  20749.752
# 287  2018-10-01  20897.804
# 288  2019-01-01  21098.827
# 289  2019-04-01  21339.121
#
# [290 rows x 2 columns]

# %%
df['growth'] = df['GDP'].pct_change(1)

# %%
df
# Out:
#            DATE        GDP    growth
# 0    1947-01-01    243.164       NaN
# 1    1947-04-01    245.968  0.011531
# 2    1947-07-01    249.585  0.014705
# 3    1947-10-01    259.745  0.040708
# 4    1948-01-01    265.742  0.023088
# ..          ...        ...       ...
# 285  2018-04-01  20510.177  0.017210
# 286  2018-07-01  20749.752  0.011681
# 287  2018-10-01  20897.804  0.007135
# 288  2019-01-01  21098.827  0.009619
# 289  2019-04-01  21339.121  0.011389
#
# [290 rows x 3 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 290 entries, 0 to 289
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   DATE    290 non-null    object
#  1   GDP     290 non-null    float64
#  2   growth  289 non-null    float64
# dtypes: float64(2), object(1)
# memory usage: 6.9+ KB

# %%
df['DATE'] = pd.to_datetime(df['DATE'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 290 entries, 0 to 289
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   DATE    290 non-null    datetime64[ns]
#  1   GDP     290 non-null    float64
#  2   growth  289 non-null    float64
# dtypes: datetime64[ns](1), float64(2)
# memory usage: 6.9 KB

# %%
df.set_index('DATE', inplace=True)
df.head()
# Out:
#                 GDP    growth
# DATE
# 1947-01-01  243.164       NaN
# 1947-04-01  245.968  0.011531
# 1947-07-01  249.585  0.014705
# 1947-10-01  259.745  0.040708
# 1948-01-01  265.742  0.023088

# %%
df['GDP'].hist()
#df['GDP'].scatter()
# Out:
# <Axes: >

# %%
df.growth.plot.hist(bins=30)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.growth.plot(kind='hist', bins=30)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# #### df.plot.area
# #### df.plot.pie
# #### df.plot.hist
# #### #### df.plot.line
# #### df.plot.scatter
# #### df.plot.bar
# #### df.plot.box
# #### df.plot.kde
# #### df.plot.density

# %%
#By default df.plot( prints line)
df.plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
df.plot.scatter(x='growth', y='GDP')
plt.show()

# %%
df.growth.plot.box()
# Out:
# <Axes: >

# %%
#Kernel Density Estimation Plot(KDE)
plt.fig(f)
df['growth'].plot.kde()

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
